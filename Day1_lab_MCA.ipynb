# %%
p = int(input("principal amount :"))
r = float(input("rate of intrest:"))
t = int(input("year:"))
x = (p*r*t)/100
print("Total intarest:",x)
print("intarest and total :",x+p)
# Out:
# principal amount : 1500
# rate of intrest: 12.5
# year: 14
# Total intarest: 2625.0
# intarest and total : 4125.0

# %%
#convert celsius to fahrenheite 

C = float(input("Enter your Celsius value : "))
F = (C*(9/5))+32
print("Fahrenheit value is :",F)
# Out:
# Enter your Celsius value :  32
# Fahrenheit value is : 89.6

# %%
# write a python script swap two number (with out using third varible)
a = int(input("Enter your first number:"))
b = int(input("Enter your seond number:"))
a = b+a
b = a-b
a= a-b
print("a =",a)
print("b =",b)
# Out:
# Enter your first number: 5
# Enter your seond number: 9
# a = 9
# b = 5

# %%
# write python program to obtain x,y,z from the users and calculate expriession :
print("linear equation : 4xpow(4) +3x pow(3) + 9z + 6 * pi ")
x = int(input("Enter the  value of x :"))
y = int(input("Enter the  value of x :"))
z = int(input("Enter the  value of x :"))
ans = (4 *(x**4)) + (3* (y**3))+(9*z)+(6*3.14)
print(ans)
# Out:
# linear equation : 4xpow(4) +3x pow(3) + 9z + 6 * pi
# Enter the  value of x : 12
# Enter the  value of x : 5
# Enter the  value of x : 7
# 83400.84

# %%
# write a python program to create  convarter for second to conver a min
sec = int(input("Enter seconds value  for convert  sec and min( integer)" ))
if sec < 0 :
    print("Please correct this input ")
else:
    if sec <60:
        print(00,"min",sec,"sec")
    else:
        x = sec % 60
        y = sec // 60
        print(y ,"min",x,"sec")
# Out:
# Enter seconds for convert to min and sec( integer) 230
# 3 min 50 sec

# %%
# write a proram for payble compound interest 
p = int(input("Enter total amount :"))
r = float(input("Enter rate of intarest :"))
t = int(input("Enter time"))
amt = p*(1+(r/100)
